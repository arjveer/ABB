# %% [markdown]
# # Scraping AI Job Board with Python
# ## ABB #6 - Session 1
#
# Code authored by: Shaw Talebi

# %% [markdown]
# ### imports

# %%
import requests
from bs4 import BeautifulSoup
import json, json5
import pandas as pd

# %% [markdown]
# ### 1) extract job listing links

# %%
# URL of the website
job_board_url = "https://aijobs.ai/united-states"

# Send a GET request to the website
response = requests.get(job_board_url)

# Check if the request was successful
if response.status_code == 200:
    # Get the HTML content
    html_content = response.text
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

# %%
# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# %%
# select all job cards on page i.e. <a> elements with class jobcardStyle1 that also have an href attribute
job_card_list = soup.select("a.jobcardStyle1[href]")

# grab all job urls on page
job_url_list = []
for job_card in job_card_list:
    job_url = job_card["href"]
    job_url_list.append(job_url)

# %%
len(job_url_list)
# Out:
# 26

# %% [markdown]
# #### repeat for 9 pages

# %%
def get_page_soup(url):

    # Send a GET request to the website
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Get the HTML content
        html_content = response.text
    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")

    return BeautifulSoup(html_content, 'html.parser')

# %%
def extract_job_urls_page(soup):
    # select all job cards on page i.e. <a> elements with class jobcardStyle1 that also have an href attribute
    job_card_list = soup.select("a.jobcardStyle1[href]")
    
    # grab all job urls on page
    job_url_list = []
    for job_card in job_card_list:
        job_url = job_card["href"]
        job_url_list.append(job_url)

    return job_url_list

# %%
# repeat for 9 pages
for page_num in range(9): 
    job_page_url = job_board_url + f'?page={page_num+2}'

    # get soup object
    soup = get_page_soup(job_page_url)
    # extract job urls
    new_job_url_list = extract_job_urls_page(soup)

    job_url_list = job_url_list + new_job_url_list

# %%
len(job_url_list)
# Out:
# 260

# %%
job_url_list
# Out:
# ['https://aijobs.ai/job/ai-agent-engineer-13',
#  'https://aijobs.ai/job/full-time-ai-developer-stealth-saas-project-ai-first-high-growth',
#  'https://aijobs.ai/job/full-time-ai-engineer-for-long-term-role-in-self-funded-company',
#  'https://aijobs.ai/job/online-data-research',
#  'https://aijobs.ai/job/full-stack-software-engineer-13',
#  'https://aijobs.ai/job/ai-prompt-engineer-part-time-flexible-schedule',
#  'https://aijobs.ai/job/senior-software-engineer-agents',
#  'https://aijobs.ai/job/lead-software-engineer-ml-backend',
#  'https://aijobs.ai/job/staff-engineer-software-autonomy-applications-r3166-3',
#  'https://aijobs.ai/job/ml-application-security-engineer',
#  'https://aijobs.ai/job/solutions-engineering-senior-manager',
#  'https://aijobs.ai/job/ml-engineer-llm-evaluation',
#  'https://aijobs.ai/job/ml-engineer-llm-safety',
#  'https://aijobs.ai/job/ml-engineer-llm-privacy',
#  'https://aijobs.ai/job/ml-research-scientist-llm-safety',
#  'https://aijobs.ai/job/staff-software-engineer-34',
#  'https://aijobs.ai/job/ml-research-engineer-llm-safety',
#  'https://aijobs.ai/job/technical-product-manager-47',
#  'https://aijobs.ai/job/study-participant-on-site-research-study',
#  'https://aijobs.ai/job/machine-learning-engineer-graduate-e-commerce-supply-chain-logistics-2026-start-phd-1',
#  'https://aijobs.ai/job/head-of-ai-solutions-2',
#  'https://aijobs.ai/job/research-scientist-in-quantum-chemistry-and-machine-learning',
#  'https://aijobs.ai/job/senior-accountant-45',
#  'https://aijobs.ai/job/senior-data-scientist-4165',
#  'https://aijobs.ai/job/machine-learning-engineer-graduate-tiktok-e-commerce-conversational-ai-2026-start-phd-1',
#  'https://aijobs.ai/job/software-engineer-systems-ml-frameworks-compilers-kernels',
#  'https://aijobs.ai/job/ai-agent-engineer-13',
#  'https://aijobs.ai/job/full-time-ai-developer-stealth-saas-project-ai-first-high-growth',
#  'https://aijobs.ai/job/full-time-ai-engineer-for-long-term-role-in-self-funded-company',
#  'https://aijobs.ai/job/online-data-research',
#  'https://aijobs.ai/job/full-stack-software-engineer-13',
#  'https://aijobs.ai/job/ai-prompt-engineer-part-time-flexible-schedule',
#  'https://aijobs.ai/job/customer-success-senior-manager',
#  'https://aijobs.ai/job/software-engineer-machine-learning-394',
#  'https://aijobs.ai/job/machine-learning-engineer-graduate-e-commerce-supply-chain-logistics-2026-start-phd',
#  'https://aijobs.ai/job/senior-cad-engineer',
#  'https://aijobs.ai/job/senior-manager-of-engineering-devex-r3569-1',
#  'https://aijobs.ai/job/head-of-customer-support',
#  'https://aijobs.ai/job/business-development-manager-automation-robotics-remote-michigan',
#  'https://aijobs.ai/job/sr-managermanager-technical-program-management-ai-data-operations',
#  'https://aijobs.ai/job/ai-engineer-remote-4',
#  'https://aijobs.ai/job/product-manager-generative-ai-and-analytics-solutions',
#  'https://aijobs.ai/job/ai-trainer-change-management-specialist-multi-bilingual-french-spanish-remote-us-canada',
#  'https://aijobs.ai/job/product-manager-ai-57',
#  'https://aijobs.ai/job/senior-consultant-it-strategy-ai-generative-ai-engineering',
#  'https://aijobs.ai/job/senior-data-scientist-4164',
#  'https://aijobs.ai/job/data-scientist-remote-52',
#  'https://aijobs.ai/job/software-engineer-137',
#  'https://aijobs.ai/job/digital-plant-engineer',
#  'https://aijobs.ai/job/artificial-intelligence-co-founder-cso-100-remote-mfd',
#  'https://aijobs.ai/job/manager-data-science-445',
#  'https://aijobs.ai/job/product-associate-ai-solutions-business-enablement',
#  'https://aijobs.ai/job/ai-agent-engineer-13',
#  'https://aijobs.ai/job/full-time-ai-developer-stealth-saas-project-ai-first-high-growth',
#  'https://aijobs.ai/job/full-time-ai-engineer-for-long-term-role-in-self-funded-company',
#  'https://aijobs.ai/job/online-data-research',
#  'https://aijobs.ai/job/full-stack-software-engineer-13',
#  'https://aijobs.ai/job/ai-prompt-engineer-part-time-flexible-schedule',
#  'https://aijobs.ai/job/staff-machine-learning-engineer-phd',
#  'https://aijobs.ai/job/business-development-manager-automation-robotics-remote-alabama',
#  'https://aijobs.ai/job/senior-software-engineer-rust',
#  'https://aijobs.ai/job/senior-program-manager-strategy-operations-3',
#  'https://aijobs.ai/job/senior-product-manager-ai-63',
#  'https://aijobs.ai/job/business-operations-ai-strategist',
#  'https://aijobs.ai/job/deployed-ai-engineer-1',
#  'https://aijobs.ai/job/data-science-co-founder-head-of-engineering-100-remote-mfd',
#  'https://aijobs.ai/job/aiml-software-engineer-iii',
#  'https://aijobs.ai/job/actuarial-data-science-senior-manager',
#  'https://aijobs.ai/job/senior-data-scientist-4161',
#  'https://aijobs.ai/job/sr-data-scientist-519',
#  'https://aijobs.ai/job/ai-automation-engineer-9',
#  'https://aijobs.ai/job/vehicle-dynamics-engineer',
#  'https://aijobs.ai/job/servicenow-solution-architect-with-ai-focus',
#  'https://aijobs.ai/job/machine-learning-engineer-2431',
#  'https://aijobs.ai/job/sr-manager-material-planning-logistics',
#  'https://aijobs.ai/job/data-quality-analyst',
#  'https://aijobs.ai/job/data-scientist-privacy',
#  'https://aijobs.ai/job/director-future-manufacturing-programs',
#  'https://aijobs.ai/job/ai-agent-engineer-13',
#  'https://aijobs.ai/job/full-time-ai-developer-stealth-saas-project-ai-first-high-growth',
#  'https://aijobs.ai/job/full-time-ai-engineer-for-long-term-role-in-self-funded-company',
#  'https://aijobs.ai/job/online-data-research',
#  'https://aijobs.ai/job/full-stack-software-engineer-13',
#  'https://aijobs.ai/job/ai-prompt-engineer-part-time-flexible-schedule',
#  'https://aijobs.ai/job/solutions-consultant-pacific-northwest',
#  'https://aijobs.ai/job/staff-ml-ranking-engineer-sd-personalization',
#  'https://aijobs.ai/job/senior-manager-insurance-client-solutions-remote-5',
#  'https://aijobs.ai/job/senior-ai-platform-engineer-7',
#  'https://aijobs.ai/job/data-science-co-founder-cpo-100-remote-mfd',
#  'https://aijobs.ai/job/backend-ai-engineer-2',
#  'https://aijobs.ai/job/solutions-engineer-85',
#  'https://aijobs.ai/job/strategic-operations-manager-sr-associate',
#  'https://aijobs.ai/job/software-engineer-accelerators',
#  'https://aijobs.ai/job/director-developer-ai',
#  'https://aijobs.ai/job/java-ai-aws-sr-lead-software-engineer',
#  'https://aijobs.ai/job/staff-data-engineer-users-listings-and-marketplace-data-ai',
#  'https://aijobs.ai/job/associate-export-compliance-analyst',
#  'https://aijobs.ai/job/sr-data-engineer-innovation-cloud-ai-emerging-tech',
#  'https://aijobs.ai/job/senior-ai-engineer-428',
#  'https://aijobs.ai/job/head-of-ai-gtm-partnerships',
#  'https://aijobs.ai/job/senior-sales-engineer-23',
#  'https://aijobs.ai/job/operator-in-residence-oir-vertical-ai-industrials',
#  'https://aijobs.ai/job/product-lead-enterprise-foundations-business-ai',
#  'https://aijobs.ai/job/research-engineer-ml-ai-computer-vision-2',
#  'https://aijobs.ai/job/ai-agent-engineer-13',
#  'https://aijobs.ai/job/full-time-ai-developer-stealth-saas-project-ai-first-high-growth',
#  'https://aijobs.ai/job/full-time-ai-engineer-for-long-term-role-in-self-funded-company',
#  'https://aijobs.ai/job/online-data-research',
#  'https://aijobs.ai/job/full-stack-software-engineer-13',
#  'https://aijobs.ai/job/ai-prompt-engineer-part-time-flexible-schedule',
#  'https://aijobs.ai/job/data-scientist-7030',
#  'https://aijobs.ai/job/senior-manager-insurance-client-solutions-remote-2',
#  'https://aijobs.ai/job/senior-director-of-product-marketing-2',
#  'https://aijobs.ai/job/machine-learning-gra-fall-2025-seal-3',
#  'https://aijobs.ai/job/software-engineer-138',
#  'https://aijobs.ai/job/staff-mobile-engineer-applied-ai',
#  'https://aijobs.ai/job/product-manager-asset-performance',
#  'https://aijobs.ai/job/cpu-core-performance-verification-intern-cpuai-hardware',
#  'https://aijobs.ai/job/senior-associate-generative-artificial-intelligence-policy-and-governance',
#  'https://aijobs.ai/job/artificial-intelligence-co-founder-cto-100-remote-mfd',
#  'https://aijobs.ai/job/senior-validation-engineer-14',
#  'https://aijobs.ai/job/ai-program-manager-marketing-strategy-operations',
#  'https://aijobs.ai/job/revenue-systems-lead',
#  'https://aijobs.ai/job/business-development-manager-automation-robotics-remote-south-carolina',
#  'https://aijobs.ai/job/machine-learning-engineer-i-windreich-department-of-artificial-intelligence-human-health',
#  'https://aijobs.ai/job/design-engineer-frontend-experiential-web',
#  'https://aijobs.ai/job/senior-security-engineer-mai-data-privacy-and-security-microsoft-ai-copilot',
#  'https://aijobs.ai/job/it-systems-technician',
#  'https://aijobs.ai/job/software-engineer-compiler-kernels-runtime',
#  'https://aijobs.ai/job/data-scientist-senior-associate-2',
#  'https://aijobs.ai/job/ai-agent-engineer-13',
#  'https://aijobs.ai/job/full-time-ai-developer-stealth-saas-project-ai-first-high-growth',
#  'https://aijobs.ai/job/full-time-ai-engineer-for-long-term-role-in-self-funded-company',
#  'https://aijobs.ai/job/online-data-research',
#  'https://aijobs.ai/job/full-stack-software-engineer-13',
#  'https://aijobs.ai/job/ai-prompt-engineer-part-time-flexible-schedule',
#  'https://aijobs.ai/job/senior-manager-insurance-client-solutions-remote-4',
#  'https://aijobs.ai/job/director-applications-aiazure-databricks-remote',
#  'https://aijobs.ai/job/strategic-partner-development-lead-chrome-ai-ecosystem',
#  'https://aijobs.ai/job/solutions-consultant-fpa-product-implementation',
#  'https://aijobs.ai/job/lead-aiml-engineer-p2122-1',
#  'https://aijobs.ai/job/sr-manager-operational-excellence-manufacturing-performance',
#  'https://aijobs.ai/job/senior-data-scientist-ads-metrics-research',
#  'https://aijobs.ai/job/machine-learning-software-engineer-associate',
#  'https://aijobs.ai/job/data-scientist-secret-clearance-in-suffolk-va',
#  'https://aijobs.ai/job/data-analyst-i-part-time-windreich-department-of-artificial-intelligence-human-health',
#  'https://aijobs.ai/job/technical-sales-engineer-1',
#  'https://aijobs.ai/job/senior-machine-learning-engineer-applied-ai-platform',
#  'https://aijobs.ai/job/ai-co-founder-cco-100-remote-mfd',
#  'https://aijobs.ai/job/senior-director-strategic-solutions-air-force-1',
#  'https://aijobs.ai/job/general-cardiac-ct-technologist-outpatient-ft-days-up-to-5000-sign-on-bonus',
#  'https://aijobs.ai/job/machine-learning-engineer-1-1',
#  'https://aijobs.ai/job/staff-applied-data-scientist-phd',
#  'https://aijobs.ai/job/manager-technical-product-management-autonomy-applications',
#  'https://aijobs.ai/job/software-engineer-backend-ai-tools-devx',
#  'https://aijobs.ai/job/data-scientist-7025',
#  'https://aijobs.ai/job/ai-agent-engineer-13',
#  'https://aijobs.ai/job/full-time-ai-developer-stealth-saas-project-ai-first-high-growth',
#  'https://aijobs.ai/job/full-time-ai-engineer-for-long-term-role-in-self-funded-company',
#  'https://aijobs.ai/job/online-data-research',
#  'https://aijobs.ai/job/full-stack-software-engineer-13',
#  'https://aijobs.ai/job/ai-prompt-engineer-part-time-flexible-schedule',
#  'https://aijobs.ai/job/director-of-data-science-aiml-optimization',
#  'https://aijobs.ai/job/staff-data-scientist-machine-learning',
#  'https://aijobs.ai/job/staff-data-engineer-data-ai-listings-structured-data',
#  'https://aijobs.ai/job/data-scientist-7039',
#  'https://aijobs.ai/job/senior-machine-learning-engineer-150k-200k-hybrid-equity-saas-outage-business-intelligence-company',
#  'https://aijobs.ai/job/senior-ml-compiler-engineer',
#  'https://aijobs.ai/job/ey-parthenon-ai-business-solutions-director',
#  'https://aijobs.ai/job/data-scientist-7015',
#  'https://aijobs.ai/job/data-scientist-7034',
#  'https://aijobs.ai/job/ai-engineer-recent-graduate',
#  'https://aijobs.ai/job/data-scientist-7022',
#  'https://aijobs.ai/job/data-scientist-7029',
#  'https://aijobs.ai/job/direct-support-professional-dsp-1-236',
#  'https://aijobs.ai/job/freelance-linguistics-consultant-ai-trainer-61',
#  'https://aijobs.ai/job/data-science-product-manager-3',
#  'https://aijobs.ai/job/simulation-lead-robotics',
#  'https://aijobs.ai/job/usa-data-scientist-iii-2',
#  'https://aijobs.ai/job/staff-data-scientist-486',
#  'https://aijobs.ai/job/vice-president-of-sales-central-us',
#  'https://aijobs.ai/job/8-month-cvml-intern-starting-2025-augsept',
#  'https://aijobs.ai/job/ai-agent-engineer-13',
#  'https://aijobs.ai/job/full-time-ai-developer-stealth-saas-project-ai-first-high-growth',
#  'https://aijobs.ai/job/full-time-ai-engineer-for-long-term-role-in-self-funded-company',
#  'https://aijobs.ai/job/online-data-research',
#  'https://aijobs.ai/job/full-stack-software-engineer-13',
#  'https://aijobs.ai/job/ai-prompt-engineer-part-time-flexible-schedule',
#  'https://aijobs.ai/job/compute-infrastructure-accounting',
#  'https://aijobs.ai/job/head-of-model-dev-platform',
#  'https://aijobs.ai/job/data-scientist-7043',
#  'https://aijobs.ai/job/immigration-sr-data-scientist-ii-job-id-556-1',
#  'https://aijobs.ai/job/senior-backend-engineer-113',
#  'https://aijobs.ai/job/validation-engineer-7',
#  'https://aijobs.ai/job/backend-software-engineer-aillm-for-ai-voice-agent-san-francisco',
#  'https://aijobs.ai/job/tech-sales',
#  'https://aijobs.ai/job/senior-product-manager-ai-for-retail',
#  'https://aijobs.ai/job/lead-software-ai-engineer',
#  'https://aijobs.ai/job/machine-learning-engineer-2025-grad',
#  'https://aijobs.ai/job/senior-engineering-manager-data-and-aiml-platforms',
#  'https://aijobs.ai/job/senior-global-security-investigator',
#  'https://aijobs.ai/job/business-modeling-applied-ai-ml-lead',
#  'https://aijobs.ai/job/principal-applied-scientist-office-ai-platform-team',
#  'https://aijobs.ai/job/charge-nurse-lvnlpn-10p-6a-63017-1',
#  'https://aijobs.ai/job/software-engineer-machine-learning-393',
#  'https://aijobs.ai/job/site-reliability-engineer-field-operations-1',
#  'https://aijobs.ai/job/tax-director-strategy-transactions',
#  'https://aijobs.ai/job/machine-learning-engineer-graduate-e-commerce-risk-control-2026-start-phd',
#  'https://aijobs.ai/job/ai-agent-engineer-13',
#  'https://aijobs.ai/job/full-time-ai-developer-stealth-saas-project-ai-first-high-growth',
#  'https://aijobs.ai/job/full-time-ai-engineer-for-long-term-role-in-self-funded-company',
#  'https://aijobs.ai/job/online-data-research',
#  'https://aijobs.ai/job/full-stack-software-engineer-13',
#  'https://aijobs.ai/job/ai-prompt-engineer-part-time-flexible-schedule',
#  'https://aijobs.ai/job/senior-counsel-product-ai',
#  'https://aijobs.ai/job/quality-assurance-qa-engineer',
#  'https://aijobs.ai/job/data-scientist-iii-172',
#  'https://aijobs.ai/job/research-scientist-intern-ai-core-machine-learning-phd',
#  'https://aijobs.ai/job/senior-director-data-and-artificial-intelligence-25025-1',
#  'https://aijobs.ai/job/data-scientist-7042',
#  'https://aijobs.ai/job/senior-director-product-management-enterprise-aiml',
#  'https://aijobs.ai/job/lead-ai-engineer-89',
#  'https://aijobs.ai/job/member-of-technical-staff-product-engineer',
#  'https://aijobs.ai/job/safety-security-manager-58436-1',
#  'https://aijobs.ai/job/security-architect-data-scientist',
#  'https://aijobs.ai/job/ainlp-engineer-generative-ai-applications-for-enterprise-network-performance-and-cybersecurity-analytics-platform',
#  'https://aijobs.ai/job/machine-learning-engineer-software-engineer-iii',
#  'https://aijobs.ai/job/department-chair-full-professor-technology-ai-and-society-college-of-engineering-and-applied-sciences',
#  'https://aijobs.ai/job/associate-director-global-medical-affairs-training-and-education',
#  'https://aijobs.ai/job/senior-manager-insurance-client-solutions-remote-3',
#  'https://aijobs.ai/job/chief-ai-officer-6',
#  'https://aijobs.ai/job/software-engineer-machine-learning-392',
#  'https://aijobs.ai/job/site-selection-enablement-leader',
#  'https://aijobs.ai/job/email-marketing-manager',
#  'https://aijobs.ai/job/ai-agent-engineer-13',
#  'https://aijobs.ai/job/full-time-ai-developer-stealth-saas-project-ai-first-high-growth',
#  'https://aijobs.ai/job/full-time-ai-engineer-for-long-term-role-in-self-funded-company',
#  'https://aijobs.ai/job/online-data-research',
#  'https://aijobs.ai/job/full-stack-software-engineer-13',
#  'https://aijobs.ai/job/ai-prompt-engineer-part-time-flexible-schedule',
#  'https://aijobs.ai/job/senior-prediction-and-planning-machine-learning-engineer-autonomous-vehicles',
#  'https://aijobs.ai/job/data-science-director-customer-service-analytics-psl',
#  'https://aijobs.ai/job/data-scientist-7038',
#  'https://aijobs.ai/job/freelance-linguistics-consultant-ai-trainer-60',
#  'https://aijobs.ai/job/senior-recruiting-coordinator-contract',
#  'https://aijobs.ai/job/sr-technical-program-manager-generative-ai-initiatives-ftvx-team',
#  'https://aijobs.ai/job/senior-data-scientist-4162',
#  'https://aijobs.ai/job/machine-learning-engineer-commerce-ads-ranking',
#  'https://aijobs.ai/job/forward-deployed-engineer-applied-ai',
#  'https://aijobs.ai/job/full-stack-software-engineer-aillm-for-ai-voice-agent-san-francisco',
#  'https://aijobs.ai/job/tech-sales-2',
#  'https://aijobs.ai/job/lead-data-scientist-828',
#  'https://aijobs.ai/job/director-product-ai-lab',
#  'https://aijobs.ai/job/data-scientist-7020',
#  'https://aijobs.ai/job/corporate-security-technical-manager',
#  'https://aijobs.ai/job/data-scientist-7021',
#  'https://aijobs.ai/job/data-scientist-for-the-lab-for-globalization-and-shared-prosperity-department-of-government-college-of-arts-sciences',
#  'https://aijobs.ai/job/senior-staff-machine-learning-engineer-end-to-end-autonomous-driving',
#  'https://aijobs.ai/job/data-scientist-7018',
#  'https://aijobs.ai/job/cpp-instructor-indypendence-58435-1']

# %% [markdown]
# ### 2) extract info from one listing

# %%
# get soup object for one job
soup = get_page_soup(job_url_list[1])

# %% [markdown]
# #### pull json data

# %%
# Find the script tag containing JSON-LD
script_tag = soup.find('script', type='application/ld+json')

# Load the JSON content
if script_tag:
    job_data = json5.loads(script_tag.string)
    
    # Extract relevant fields
    company_name = job_data['hiringOrganization']['name']
    job_title = job_data['title']
    job_description = job_data['description']
    salary_min = job_data['baseSalary']['value']['minValue']
    salary_max = job_data['baseSalary']['value']['maxValue']
    location = job_data['jobLocation']['address']['addressRegion']

    # Print extracted data
    print(f"Company Name: {company_name}")
    print(f"Job Title: {job_title}")
    print(f"Job Description: {job_description[:200]}...")
    print(f"Salary Range: {salary_min} - {salary_max} USD")
    print(f"Location: {location}")
# Out:
# Company Name: Tyron Humphris
# Job Title: Full-Time AI Developer – Stealth SaaS Project (AI-First, High Growth)
# Job Description: <p>We’re building a cutting-edge B2B SaaS platform that leverages AI agents, real-time data aggregation, and multi-source intelligence to surface high-value business insights. We’re looking for a self...
# Salary Range: 250001 - 250001 USD
# Location: Florida

# %% [markdown]
# ### 3) extract info from all listings

# %%
def extract_job_info(url):
    """
    Extracts job information from a given job listing URL.

    Args:
        url (str): The URL of the job listing.

    Returns:
        dict: A dictionary containing the following key-value pairs:
            - 'company_name' (str): Name of the hiring organization.
            - 'job_title' (str): Title of the job.
            - 'job_description' (str): Detailed description of the job.
            - 'salary_min' (float or str): Minimum salary offered for the job.
            - 'salary_max' (float or str): Maximum salary offered for the job.
               Returns 'N/A' if salary information is unavailable.
    """
    try:
        # get soup object
        soup = get_page_soup(url)
        
        # Find the script tag containing JSON-LD
        script_tag = soup.find('script', type='application/ld+json')
        
        if script_tag:
            job_data = json5.loads(script_tag.string)
            
            # Extract relevant fields with default values if not present
            company_name = job_data.get('hiringOrganization', {}).get('name', 'N/A')
            job_title = job_data.get('title', 'N/A')
            job_description = job_data.get('description', 'N/A')
            salary_data = job_data.get('baseSalary', {}).get('value', {})
            salary_min = salary_data.get('minValue', 'N/A')
            salary_max = salary_data.get('maxValue', 'N/A')
            location = job_data.get('jobLocation', {}).get('address', {}).get('addressRegion', 'N/A')
            
            return {
                'company_name': company_name,
                'job_title': job_title,
                'job_description': job_description,
                'salary_min': salary_min,
                'salary_max': salary_max,
                'location': location
            }
        else:
            return {'error': 'No JSON-LD script found in the page'}
    
    except requests.RequestException as e:
        return {'error': f"Request failed: {e}"}
    
    except Exception as e:
        return {'error': f"An unexpected error occurred: {e}"}

# %%
# extract job info from all job urls
job_info_list = []
raw_JSON_list = []

for job_url in job_url_list:
    # extract job info
    job_info = extract_job_info(job_url)

    # store results in list if no errors occured
    try:
        print(job_info["job_title"])
        job_info_list.append(job_info)
    except:
        print(f"Could not extract info from: {job_url}.")
        
    # save raw JSON-LD
    soup = get_page_soup(job_url)
    script_tag = soup.find('script', type='application/ld+json')
    
    raw_JSON_list.append({"job_url": job_url, "JSON": script_tag})
# Out:
# Could not extract info from: https://aijobs.ai/job/ai-agent-engineer-13.
# Full-Time AI Developer – Stealth SaaS Project (AI-First, High Growth)
# Could not extract info from: https://aijobs.ai/job/full-time-ai-engineer-for-long-term-role-in-self-funded-company.
# Could not extract info from: https://aijobs.ai/job/online-data-research.
# Could not extract info from: https://aijobs.ai/job/full-stack-software-engineer-13.
# AI Prompt Engineer - PART TIME, FLEXIBLE SCHEDULE
# Could not extract info from: https://aijobs.ai/job

# Could not extract info from: https://aijobs.ai/job/full-stack-software-engineer-13.
# AI Prompt Engineer - PART TIME, FLEXIBLE SCHEDULE
# Senior Prediction and Planning Machine Learning Engineer - Autonomous Vehicles
# Could not extract info from: https://aijobs.ai/job/data-science-director-customer-service-analytics-psl.
# Could not extract info from: https://aijobs.ai/job/data-scientist-7038.
# Could not extract info from: https://aijobs.ai/job/freelance-linguistics-consultant-ai-trainer-60.
# Senior Recruiting Coordinator (Contract)
# Sr. Technical Program Manager - Generative AI Initiatives, FTVX Team
# Could not extract info from: https://aijobs.ai/job/senior-data-scientist-4162.
# Could not extract info from: https://aijobs.ai/job/machine-learning-engineer-commerce-ads-ranking.
# Could not extract info from: https://aijobs.ai/job/forward-deployed-engineer-applied-ai.
# Could not extract info from: https://aijobs.ai/job/full-stack-software-engineer-aillm-for-ai-voice-agent-san-francisco.
# Could not extract info from: https://aijobs.ai/job/tech-sales-2.
# Could not extract info from: https://aijobs.ai/job/lead-data-scientist-828.
# Could not extract info from: https://aijobs.ai/job/director-product-ai-lab.
# Data Scientist
# Could not extract info from: https://aijobs.ai/job/corporate-security-technical-manager.
# Data Scientist
# Data Scientist for the Lab for Globalization and Shared Prosperity, Department of Government - College of Arts &amp; Sciences
# Could not extract info from: https://aijobs.ai/job/senior-staff-machine-learning-engineer-end-to-end-autonomous-driving.
# Data Scientist
# Could not extract info from: https://aijobs.ai/job/cpp-instructor-indypendence-58435-1.

# %% [markdown]
# ### 4) Store data in Pandas dataframe

# %%
df = pd.DataFrame(job_info_list)
df.head()
# Out:
#      company_name                                          job_title  \
# 0  Tyron Humphris  Full-Time AI Developer – Stealth SaaS Project ...
# 1       Meir Levy  AI Prompt Engineer - PART TIME, FLEXIBLE SCHEDULE
# 2       ByteDance  Machine Learning Engineer Graduate (E-Commerce...
# 3       ByteDance  Research Scientist in Quantum Chemistry and Ma...
# 4       ByteDance  Machine Learning Engineer Graduate (TikTok E-C...
#
#                                      job_description  salary_min  salary_max  \
# 0  <p>We’re building a cutting-edge B2B SaaS plat...      250001      250001
# 1  <p>Looking for an AI Prompt Engineer OR a very...          50          50
# 2  ResponsibilitiesTeam Introduction:Join the E-c...      237500      237500
# 3  ResponsibilitiesAbout the team:Our team at Byt...      355000      355000
# 4  ResponsibilitiesTeam Introduction:Our team is ...      237500      237500
#
#      location
# 0     Florida
# 1  California
# 2         N/A
# 3         N/A
# 4         N/A

# %%
df.shape
# Out:
# (72, 6)

# %%
# save to file
df.to_csv("data/ai_job_data.csv", index=False)

# %%
# save raw JSON
with open("data/raw_json_list.jsonl", "w", encoding="utf-8") as f:
    for item in raw_JSON_list:
        tag = item.get("JSON")
        parsed = None
        if tag:
            text = tag.string or tag.get_text(strip=True)
            if text:
                try:
                    parsed = json5.loads(text)  # parsed dict
                except Exception:
                    parsed = text  # fallback to raw string
        rec = {"job_url": item.get("job_url"), "jsonld": parsed}
        f.write(json.dumps(rec, ensure_ascii=False) + "\n")
